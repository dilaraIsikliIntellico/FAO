# %%
import pandas as pd
import docx
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1.Percentage of children under 5 years of age who are stunted (modelled estimates) (percent)

# %%
root = '/home/dila-isi/PycharmProjects/homealarms/FAO/FOOD UTILIZATION/'
file = '/Percentage of children under 5 years.csv'

colombia = pd.read_csv(root + 'Colombia' + file)
ecuador = pd.read_csv(root + 'Ecuador' + file)
georgia = pd.read_csv(root + 'Georgia' + file)
peru = pd.read_csv(root + 'Peru' + file)
vietnam = pd.read_csv(root + 'Vietnam' + file)

# %%
colombia=colombia[colombia['Item']=='Percentage of children under 5 years of age who are stunted (modelled estimates) (percent)']
ecuador = ecuador[ecuador['Item']=='Percentage of children under 5 years of age who are stunted (modelled estimates) (percent)']
georgia= georgia[georgia['Item']=='Percentage of children under 5 years of age who are stunted (modelled estimates) (percent)']
peru = peru[peru['Item']=='Percentage of children under 5 years of age who are stunted (modelled estimates) (percent)']
vietnam = vietnam[vietnam['Item']=='Percentage of children under 5 years of age who are stunted (modelled estimates) (percent)']

# %%
colombia.set_index('Year', inplace=True)
ecuador.set_index('Year', inplace=True)
georgia.set_index('Year', inplace=True)
peru.set_index('Year', inplace=True)
vietnam.set_index('Year', inplace=True)
colombia = colombia.tail(9)
ecuador = ecuador.tail(9)
georgia = georgia.tail(9)
peru = peru.tail(9)
vietnam = vietnam.tail(9)

# %%
dfSummary=pd.DataFrame({"Country":['Colombia', 'Ecuador', 'Georgia','Peru', 'Vietnam', ]})
dfList=[colombia, ecuador, georgia, peru,vietnam ]

min,max,mean,std = [],[],[],[]
for df in dfList:
    min.append("%.2f" % df['Value'].min())
    max.append("%.2f" % df['Value'].max())
    mean.append("%.2f" % df['Value'].mean())
    std.append("%.2f" % df['Value'].std())

dfSummary['Mean']=mean
dfSummary['S.D.']=std
dfSummary['Min.']=min
dfSummary['Max.']=max

# %%
dfSummary
# Out:
#     Country   Mean  S.D.   Min.   Max.
# 0  Colombia  12.20  0.51  11.50  12.90
# 1   Ecuador  23.43  0.28  23.10  24.10
# 2   Georgia   7.22  1.23   5.70   9.20
# 3      Peru  14.28  2.76  10.80  18.80
# 4   Vietnam  24.06  1.29  22.30  25.90

# %%
df = dfSummary
# Initialise the Word document
doc = docx.Document()
# Initialise the table
t = doc.add_table(rows=1, cols=df.shape[1])
# Add borders
t.style = 'TableGrid'
# Add the column headings
for j in range(df.shape[1]):
    t.cell(0, j).text = df.columns[j]
# Add the body of the data frame
for i in range(df.shape[0]):
    row = t.add_row()
    for j in range(df.shape[1]):
        cell = df.iat[i, j]
        row.cells[j].text = str(cell)
# Save the Word doc
doc.save('Percentage of children under 5 years of age who are stunted.docx')
# Out:
# /home/dila-isi/.conda/envs/homealarms/lib/python3.10/site-packages/docx/styles/styles.py:139: UserWarning: style lookup by style_id is deprecated. Use style name as key instead.
#   return self._get_style_id_from_style(self[style_name], style_type)

# %%
plt.subplots(figsize=(10, 5))
plt.plot(colombia['Value'], label='Colombia', color='green', marker='o')
plt.plot(ecuador['Value'], label='Ecuador', color='steelblue', marker='o')
plt.plot(georgia['Value'], label='Georgia', color='purple', marker='o')
plt.plot(peru['Value'], label='Peru', color='black', marker='o')
plt.plot(vietnam['Value'], label='Vietnam', color='red', marker='o')
plt.title('Prevalence of anemia among women of reproductive age (15-49 years)', fontsize=12)
plt.legend(title='Country')
plt.ylim(5,27)
plt.ylabel('%', fontsize=14)
plt.legend()

# %% [markdown]
# ## Percentage of children under 5 years of age who are overweight (modelled estimates) (percent)

# %%
colombia = pd.read_csv(root + 'Colombia' + file)
ecuador = pd.read_csv(root + 'Ecuador' + file)
georgia = pd.read_csv(root + 'Georgia' + file)
peru = pd.read_csv(root + 'Peru' + file)
vietnam = pd.read_csv(root + 'Vietnam' + file)

item_name = 'Percentage of children under 5 years of age who are overweight (modelled estimates) (percent)'

colombia=colombia[colombia['Item']==item_name]
ecuador = ecuador[ecuador['Item']== item_name]
georgia= georgia[georgia['Item']== item_name]
peru = peru[peru['Item']== item_name]
vietnam = vietnam[vietnam['Item']==item_name]

# %%
colombia
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 2           FS  Suite of Food Security Indicators         44  Colombia
# 4           FS  Suite of Food Security Indicators         44  Colombia
# 6           FS  Suite of Food Security Indicators         44  Colombia
# 8           FS  Suite of Food Security Indicators         44  Colombia
# 10          FS  Suite of Food Security Indicators         44  Colombia
# 13          FS  Suite of Food Security Indicators         44  Colombia
# 15          FS  Suite of Food Security Indicators         44  Colombia
# 17          FS  Suite of Food Security Indicators         44  Colombia
# 19          FS  Suite of Food Security Indicators         44  Colombia
# 21          FS  Suite of Food Security Indicators         44  Colombia
# 24          FS  Suite of Food Security Indicators         44  Colombia
# 26          FS  Suite of Food Security Indicators         44  Colombia
# 28          FS  Suite of Food Security Indicators         44  Colombia
# 30          FS  Suite of Food Security Indicators         44  Colombia
# 32          FS  Suite of Food Security Indicators         44  Colombia
# 34          FS  Suite of Food Security Indicators         44  Colombia
# 37          FS  Suite of Food Security Indicators         44  Colombia
# 39          FS  Suite of Food Security Indicators         44  Colombia
# 41          FS  Suite of Food Security Indicators         44  Colombia
# 43          FS  Suite of Food Security Indicators         44  Colombia
# 45          FS  Suite of Food Security Indicators         44  Colombia
#
#     Element Code Element  Item Code  \
# 2           6121   Value      21041
# 4           6121   Value      21041
# 6           6121   Value      21041
# 8           6121   Value      21041
# 10          6121   Value      21041
# 13          6121   Value      21041
# 15          6121   Value      21041
# 17          6121   Value      21041
# 19          6121   Value      21041
# 21          6121   Value      21041
# 24          6121   Value      21041
# 26          6121   Value      21041
# 28          6121   Value      21041
# 30          6121   Value      21041
# 32          6121   Value      21041
# 34          6121   Value      21041
# 37          6121   Value      21041
# 39          6121   Value      21041
# 41          6121   Value      21041
# 43          6121   Value      21041
# 45          6121   Value      21041
#
#                                                  Item  Year Code  Year Unit  \
# 2   Percentage of children under 5 years of age wh...       2000  2000    %
# 4   Percentage of children under 5 years of age wh...       2001  2001    %
# 6   Percentage of children under 5 years of age wh...       2002  2002    %
# 8   Percentage of children under 5 years of age wh...       2003  2003    %
# 10  Percentage of children under 5 years of age wh...       2004  2004    %
# 13  Percentage of children under 5 years of age wh...       2005  2005    %
# 15  Percentage of children under 5 years of age wh...       2006  2006    %
# 17  Percentage of children under 5 years of age wh...       2007  2007    %
# 19  Percentage of children under 5 years of age wh...       2008  2008    %
# 21  Percentage of children under 5 years of age wh...       2009  2009    %
# 24  Percentage of children under 5 years of age wh...       2010  2010    %
# 26  Percentage of children under 5 years of age wh...       2011  2011    %
# 28  Percentage of children under 5 years of age wh...       2012  2012    %
# 30  Percentage of children under 5 years of age wh...       2013  2013    %
# 32  Percentage of children under 5 years of age wh...       2014  2014    %
# 34  Percentage of children under 5 years of age wh...       2015  2015    %
# 37  Percentage of children under 5 years of age wh...       2016  2016    %
# 39  Percentage of children under 5 years of age wh...       2017  2017    %
# 41  Percentage of children under 5 years of age wh...       2018  2018    %
# 43  Percentage of children under 5 years of age wh...       2019  2019    %
# 45  Percentage of children under 5 years of age wh...       2020  2020    %
#
#     Value Flag                         Flag Description  Note
# 2     4.7    X  Figure from international organizations   NaN
# 4     4.7    X  Figure from international organizations   NaN
# 6     4.8    X  Figure from international organizations   NaN
# 8     4.8    X  Figure from international organizations   NaN
# 10    4.8    X  Figure from international organizations   NaN
# 13    4.8    X  Figure from international organizations   NaN
# 15    4.8    X  Figure from international organizations   NaN
# 17    4.9    X  Figure from international organizations   NaN
# 19    4.9    X  Figure from international organizations   NaN
# 21    5.0    X  Figure from international organizations   NaN
# 24    5.1    X  Figure from international organizations   NaN
# 26    5.1    X  Figure from international organizations   NaN
# 28    5.2    X  Figure from international organizations   NaN
# 30    5.3    X  Figure from international organizations   NaN
# 32    5.3    X  Figure from international organizations   NaN
# 34    5.4    X  Figure from international organizations   NaN
# 37    5.5    X  Figure from international organizations   NaN
# 39    5.6    X  Figure from international organizations   NaN
# 41    5.6    X  Figure from international organizations   NaN
# 43    5.7    X  Figure from international organizations   NaN
# 45    5.8    X  Figure from international organizations   NaN

# %%
colombia.set_index('Year', inplace=True)
ecuador.set_index('Year', inplace=True)
georgia.set_index('Year', inplace=True)
peru.set_index('Year', inplace=True)
vietnam.set_index('Year', inplace=True)
colombia = colombia.tail(9)
ecuador = ecuador.tail(9)
georgia = georgia.tail(9)
peru = peru.tail(9)
vietnam = vietnam.tail(9)
dfSummary = pd.DataFrame({"Country": ['Colombia', 'Ecuador', 'Georgia', 'Peru', 'Vietnam']})
dfList = [colombia, ecuador, georgia, peru, vietnam]

min, max, mean, std = [], [], [], []
for df in dfList:
    min.append("%.2f" % df['Value'].min())
    max.append("%.2f" % df['Value'].max())
    mean.append("%.2f" % df['Value'].mean())
    std.append("%.2f" % df['Value'].std())

dfSummary['Mean'] = mean
dfSummary['S.D.'] = std
dfSummary['Min.'] = min
dfSummary['Max.'] = max

# %%
dfSummary
# Out:
#     Country   Mean  S.D.  Min.   Max.
# 0  Colombia   5.49  0.20  5.20   5.80
# 1   Ecuador   8.59  0.89  7.30   9.80
# 2   Georgia  10.11  2.13  7.60  13.70
# 3      Peru   8.32  0.24  8.00   8.70
# 4   Vietnam   5.10  0.63  4.20   6.00

# %%
df = dfSummary
# Initialise the Word document
doc = docx.Document()
# Initialise the table
t = doc.add_table(rows=1, cols=df.shape[1])
# Add borders
t.style = 'TableGrid'
# Add the column headings
for j in range(df.shape[1]):
    t.cell(0, j).text = df.columns[j]
# Add the body of the data frame
for i in range(df.shape[0]):
    row = t.add_row()
    for j in range(df.shape[1]):
        cell = df.iat[i, j]
        row.cells[j].text = str(cell)
# Save the Word doc
doc.save('Percentage of children under 5 years of age who are overweight.docx')
# Out:
# /home/dila-isi/.conda/envs/homealarms/lib/python3.10/site-packages/docx/styles/styles.py:139: UserWarning: style lookup by style_id is deprecated. Use style name as key instead.
#   return self._get_style_id_from_style(self[style_name], style_type)

# %%
plt.subplots(figsize=(10, 5))
plt.plot(colombia['Value'], label='Colombia', color='green', marker='o')
plt.plot(ecuador['Value'], label='Ecuador', color='steelblue', marker='o')
plt.plot(georgia['Value'], label='Georgia', color='purple', marker='o')
plt.plot(peru['Value'], label='Peru', color='black', marker='o')
plt.plot(vietnam['Value'], label='Vietnam', color='red', marker='o')
plt.title('Percentage of children under 5 years affected by wasting (percent)', fontsize=12)
plt.legend(title='Country')
plt.ylim(4,14)
plt.ylabel('%', fontsize=14)
plt.legend()

# %% [markdown]
# ## Percentage of children under 5 years affected by wasting (percent)

# %%
colombia = pd.read_csv(root + 'Colombia' + file)
ecuador = pd.read_csv(root + 'Ecuador' + file)
georgia = pd.read_csv(root + 'Georgia' + file)
peru = pd.read_csv(root + 'Peru' + file)
vietnam = pd.read_csv(root + 'Vietnam' + file)
item_name= 'Percentage of children under 5 years affected by wasting (percent)'

colombia=colombia[colombia['Item']==item_name]
ecuador = ecuador[ecuador['Item']== item_name]
georgia= georgia[georgia['Item']== item_name]
peru = peru[peru['Item']== item_name]
vietnam = vietnam[vietnam['Item']==item_name]

# %%
colombia.set_index('Year', inplace=True)
ecuador.set_index('Year', inplace=True)
georgia.set_index('Year', inplace=True)
peru.set_index('Year', inplace=True)
vietnam.set_index('Year', inplace=True)

# %%
colombia
# Out:
#      Domain Code                             Domain  Area Code      Area  \
# Year
# 2000          FS  Suite of Food Security Indicators         44  Colombia
# 2005          FS  Suite of Food Security Indicators         44  Colombia
# 2010          FS  Suite of Food Security Indicators         44  Colombia
# 2016          FS  Suite of Food Security Indicators         44  Colombia
#
#       Element Code Element  Item Code  \
# Year
# 2000          6121   Value      21026
# 2005          6121   Value      21026
# 2010          6121   Value      21026
# 2016          6121   Value      21026
#
#                                                    Item  Year Code Unit  \
# Year
# 2000  Percentage of children under 5 years affected ...       2000    %
# 2005  Percentage of children under 5 years affected ...       2005    %
# 2010  Percentage of children under 5 years affected ...       2010    %
# 2016  Percentage of children under 5 years affected ...       2016    %
#
#       Value Flag                         Flag Description  Note
# Year
# 2000    1.0    X  Figure from international organizations   NaN
# 2005    1.6    X  Figure from international organizations   NaN
# 2010    0.9    X  Figure from international organizations   NaN
# 2016    1.6    X  Figure from international organizations   NaN

# %%
ecuador
# Out:
#      Domain Code                             Domain  Area Code     Area  \
# Year
# 2004          FS  Suite of Food Security Indicators         58  Ecuador
# 2006          FS  Suite of Food Security Indicators         58  Ecuador
# 2012          FS  Suite of Food Security Indicators         58  Ecuador
# 2014          FS  Suite of Food Security Indicators         58  Ecuador
# 2019          FS  Suite of Food Security Indicators         58  Ecuador
#
#       Element Code Element  Item Code  \
# Year
# 2004          6121   Value      21026
# 2006          6121   Value      21026
# 2012          6121   Value      21026
# 2014          6121   Value      21026
# 2019          6121   Value      21026
#
#                                                    Item  Year Code Unit  \
# Year
# 2004  Percentage of children under 5 years affected ...       2004    %
# 2006  Percentage of children under 5 years affected ...       2006    %
# 2012  Percentage of children under 5 years affected ...       2012    %
# 2014  Percentage of children under 5 years affected ...       2014    %
# 2019  Percentage of children under 5 years affected ...       2019    %
#
#       Value Flag                         Flag Description  Note
# Year
# 2004    2.0    X  Figure from international organizations   NaN
# 2006    2.1    X  Figure from international organizations   NaN
# 2012    2.4    X  Figure from international organizations   NaN
# 2014    1.6    X  Figure from international organizations   NaN
# 2019    3.7    X  Figure from international organizations   NaN

# %%
georgia
# Out:
#      Domain Code                             Domain  Area Code     Area  \
# Year
# 2005          FS  Suite of Food Security Indicators         73  Georgia
# 2009          FS  Suite of Food Security Indicators         73  Georgia
# 2018          FS  Suite of Food Security Indicators         73  Georgia
#
#       Element Code Element  Item Code  \
# Year
# 2005          6121   Value      21026
# 2009          6121   Value      21026
# 2018          6121   Value      21026
#
#                                                    Item  Year Code Unit  \
# Year
# 2005  Percentage of children under 5 years affected ...       2005    %
# 2009  Percentage of children under 5 years affected ...       2009    %
# 2018  Percentage of children under 5 years affected ...       2018    %
#
#       Value Flag                         Flag Description  Note
# Year
# 2005    3.0    X  Figure from international organizations   NaN
# 2009    1.3    X  Figure from international organizations   NaN
# 2018    0.6    X  Figure from international organizations   NaN

# %%
peru
# Out:
#      Domain Code                             Domain  Area Code  Area  \
# Year
# 2000          FS  Suite of Food Security Indicators        170  Peru
# 2005          FS  Suite of Food Security Indicators        170  Peru
# 2007          FS  Suite of Food Security Indicators        170  Peru
# 2009          FS  Suite of Food Security Indicators        170  Peru
# 2010          FS  Suite of Food Security Indicators        170  Peru
# 2011          FS  Suite of Food Security Indicators        170  Peru
# 2012          FS  Suite of Food Security Indicators        170  Peru
# 2013          FS  Suite of Food Security Indicators        170  Peru
# 2014          FS  Suite of Food Security Indicators        170  Peru
# 2015          FS  Suite of Food Security Indicators        170  Peru
# 2016          FS  Suite of Food Security Indicators        170  Peru
# 2017          FS  Suite of Food Security Indicators        170  Peru
# 2018          FS  Suite of Food Security Indicators        170  Peru
# 2019          FS  Suite of Food Security Indicators        170  Peru
#
#       Element Code Element  Item Code  \
# Year
# 2000          6121   Value      21026
# 2005          6121   Value      21026
# 2007          6121   Value      21026
# 2009          6121   Value      21026
# 2010          6121   Value      21026
# 2011          6121   Value      21026
# 2012          6121   Value      21026
# 2013          6121   Value      21026
# 2014          6121   Value      21026
# 2015          6121   Value      21026
# 2016          6121   Value      21026
# 2017          6121   Value      21026
# 2018          6121   Value      21026
# 2019          6121   Value      21026
#
#                                                    Item  Year Code Unit  \
# Year
# 2000  Percentage of children under 5 years affected ...       2000    %
# 2005  Percentage of children under 5 years affected ...       2005    %
# 2007  Percentage of children under 5 years affected ...       2007    %
# 2009  Percentage of children under 5 years affected ...       2009    %
# 2010  Percentage of children under 5 years affected ...       2010    %
# 2011  Percentage of children under 5 years affected ...       2011    %
# 2012  Percentage of children under 5 years affected ...       2012    %
# 2013  Percentage of children under 5 years affected ...       2013    %
# 2014  Percentage of children under 5 years affected ...       2014    %
# 2015  Percentage of children under 5 years affected ...       2015    %
# 2016  Percentage of children under 5 years affected ...       2016    %
# 2017  Percentage of children under 5 years affected ...       2017    %
# 2018  Percentage of children under 5 years affected ...       2018    %
# 2019  Percentage of children under 5 years affected ...       2019    %
#
#       Value Flag                         Flag Description  Note
# Year
# 2000    1.1    X  Figure from international organizations   NaN
# 2005    1.0    X  Figure from international organizations   NaN
# 2007    0.8    X  Figure from international organizations   NaN
# 2009    0.6    X  Figure from international organizations   NaN
# 2010    0.7    X  Figure from international organizations   NaN
# 2011    0.4    X  Figure from international organizations   NaN
# 2012    0.6    X  Figure from international organizations   NaN
# 2013    0.4    X  Figure from international organizations   NaN
# 2014    0.6    X  Figure from international organizations   NaN
# 2015    0.6    X  Figure from international organizations   NaN
# 2016    0.6    X  Figure from international organizations   NaN
# 2017    0.5    X  Figure from international organizations   NaN
# 2018    0.5    X  Figure from international organizations   NaN
# 2019    0.4    X  Figure from international organizations   NaN

# %%
vietnam
# Out:
#      Domain Code                             Domain  Area Code      Area  \
# Year
# 2000          FS  Suite of Food Security Indicators        237  Viet Nam
# 2002          FS  Suite of Food Security Indicators        237  Viet Nam
# 2003          FS  Suite of Food Security Indicators        237  Viet Nam
# 2004          FS  Suite of Food Security Indicators        237  Viet Nam
# 2005          FS  Suite of Food Security Indicators        237  Viet Nam
# 2006          FS  Suite of Food Security Indicators        237  Viet Nam
# 2007          FS  Suite of Food Security Indicators        237  Viet Nam
# 2008          FS  Suite of Food Security Indicators        237  Viet Nam
# 2009          FS  Suite of Food Security Indicators        237  Viet Nam
# 2010          FS  Suite of Food Security Indicators        237  Viet Nam
# 2011          FS  Suite of Food Security Indicators        237  Viet Nam
# 2012          FS  Suite of Food Security Indicators        237  Viet Nam
# 2013          FS  Suite of Food Security Indicators        237  Viet Nam
# 2014          FS  Suite of Food Security Indicators        237  Viet Nam
# 2015          FS  Suite of Food Security Indicators        237  Viet Nam
# 2017          FS  Suite of Food Security Indicators        237  Viet Nam
#
#       Element Code Element  Item Code  \
# Year
# 2000          6121   Value      21026
# 2002          6121   Value      21026
# 2003          6121   Value      21026
# 2004          6121   Value      21026
# 2005          6121   Value      21026
# 2006          6121   Value      21026
# 2007          6121   Value      21026
# 2008          6121   Value      21026
# 2009          6121   Value      21026
# 2010          6121   Value      21026
# 2011          6121   Value      21026
# 2012          6121   Value      21026
# 2013          6121   Value      21026
# 2014          6121   Value      21026
# 2015          6121   Value      21026
# 2017          6121   Value      21026
#
#                                                    Item  Year Code Unit  \
# Year
# 2000  Percentage of children under 5 years affected ...       2000    %
# 2002  Percentage of children under 5 years affected ...       2002    %
# 2003  Percentage of children under 5 years affected ...       2003    %
# 2004  Percentage of children under 5 years affected ...       2004    %
# 2005  Percentage of children under 5 years affected ...       2005    %
# 2006  Percentage of children under 5 years affected ...       2006    %
# 2007  Percentage of children under 5 years affected ...       2007    %
# 2008  Percentage of children under 5 years affected ...       2008    %
# 2009  Percentage of children under 5 years affected ...       2009    %
# 2010  Percentage of children under 5 years affected ...       2010    %
# 2011  Percentage of children under 5 years affected ...       2011    %
# 2012  Percentage of children under 5 years affected ...       2012    %
# 2013  Percentage of children under 5 years affected ...       2013    %
# 2014  Percentage of children under 5 years affected ...       2014    %
# 2015  Percentage of children under 5 years affected ...       2015    %
# 2017  Percentage of children under 5 years affected ...       2017    %
#
#       Value Flag                         Flag Description  Note
# Year
# 2000    6.1    X  Figure from international organizations   NaN
# 2002    8.9    X  Figure from international organizations   NaN
# 2003   10.9    X  Figure from international organizations   NaN
# 2004   11.3    X  Figure from international organizations   NaN
# 2005   10.7    X  Figure from international organizations   NaN
# 2006    9.9    X  Figure from international organizations   NaN
# 2007   10.1    X  Figure from international organizations   NaN
# 2008    9.7    X  Figure from international organizations   NaN
# 2009    7.1    X  Figure from international organizations   NaN
# 2010    4.1    X  Figure from international organizations   NaN
# 2011    6.6    X  Figure from international organizations   NaN
# 2012    6.7    X  Figure from international organizations   NaN
# 2013    6.6    X  Figure from international organizations   NaN
# 2014    6.8    X  Figure from international organizations   NaN
# 2015    6.4    X  Figure from international organizations   NaN
# 2017    5.8    X  Figure from international organizations   NaN

# %%
colombia(1)
ecuador(3)
georgia(1)
peru(9)
vietnam(7)

# %%
dfSummary = pd.DataFrame({"Country": ['Colombia', 'Ecuador', 'Georgia', 'Peru', 'Vietnam']})
dfList = [colombia, ecuador, georgia, peru, vietnam]

min, max, mean, std = [], [], [], []
for df in dfList:
    min.append("%.2f" % df['Value'].min())
    max.append("%.2f" % df['Value'].max())
    mean.append("%.2f" % df['Value'].mean())
    std.append("%.2f" % df['Value'].std())

dfSummary['Mean'] = mean
dfSummary['S.D.'] = std
dfSummary['Min.'] = min
dfSummary['Max.'] = max

# %%
df = dfSummary
# Initialise the Word document
doc = docx.Document()
# Initialise the table
t = doc.add_table(rows=1, cols=df.shape[1])
# Add borders
t.style = 'TableGrid'
# Add the column headings
for j in range(df.shape[1]):
    t.cell(0, j).text = df.columns[j]
# Add the body of the data frame
for i in range(df.shape[0]):
    row = t.add_row()
    for j in range(df.shape[1]):
        cell = df.iat[i, j]
        row.cells[j].text = str(cell)
# Save the Word doc
doc.save('.docx')

# %%
plt.subplots(figsize=(10, 5))
plt.plot(colombia['Value'], label='Colombia', color='green', marker='o')
plt.plot(ecuador['Value'], label='Ecuador', color='steelblue', marker='o')
plt.plot(georgia['Value'], label='Georgia', color='purple', marker='o')
plt.plot(peru['Value'], label='Peru', color='black', marker='o')
plt.plot(vietnam['Value'], label='Vietnam', color='red', marker='o')
plt.title('', fontsize=12)
plt.legend(title='Country')
plt.ylim(5, 27)
plt.ylabel('%', fontsize=14)
plt.legend()
