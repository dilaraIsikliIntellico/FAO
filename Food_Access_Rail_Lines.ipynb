# %%
import pandas as pd
import docx
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1-Rail lines density

# %% [markdown]
# # NO DATASET FOR COLOMBIA

# %%
root = '/home/dila-isi/PycharmProjects/homealarms/FAO/FOOD ACCESS/'
file = '/Rail lines density.csv'

#colombia = pd.read_csv(root + 'Colombia' + file)
#ecuador = pd.read_csv(root + 'Ecuador' + file)
georgia = pd.read_csv(root + 'Georgia' + file)
#peru = pd.read_csv(root + 'Peru' + file)
vietnam = pd.read_csv(root + 'Vietnam' + file)

# %%
georgia.tail(8)
# Out:
#    Domain Code                             Domain  Area Code     Area  \
# 11          FS  Suite of Food Security Indicators         73  Georgia
# 12          FS  Suite of Food Security Indicators         73  Georgia
# 13          FS  Suite of Food Security Indicators         73  Georgia
# 14          FS  Suite of Food Security Indicators         73  Georgia
# 15          FS  Suite of Food Security Indicators         73  Georgia
# 16          FS  Suite of Food Security Indicators         73  Georgia
# 17          FS  Suite of Food Security Indicators         73  Georgia
# 18          FS  Suite of Food Security Indicators         73  Georgia
#
#     Element Code Element  Item Code  \
# 11          6124   Value      21016
# 12          6124   Value      21016
# 13          6124   Value      21016
# 14          6124   Value      21016
# 15          6124   Value      21016
# 16          6124   Value      21016
# 17          6124   Value      21016
# 18          6124   Value      21016
#
#                                                  Item  Year Code  Year  \
# 11  Rail lines density (total route in km per 100 ...       2011  2011
# 12  Rail lines density (total route in km per 100 ...       2012  2012
# 13  Rail lines density (total route in km per 100 ...       2013  2013
# 14  Rail lines density (total route in km per 100 ...       2014  2014
# 15  Rail lines density (total route in km per 100 ...       2015  2015
# 16  Rail lines density (total route in km per 100 ...       2016  2016
# 17  Rail lines density (total route in km per 100 ...       2017  2017
# 18  Rail lines density (total route in km per 100 ...       2018  2018
#
#                               Unit  Value Flag  \
# 11  per 100 square km of land area    1.8    X
# 12  per 100 square km of land area    2.3    X
# 13  per 100 square km of land area    2.1    X
# 14  per 100 square km of land area    2.1    X
# 15  per 100 square km of land area    2.1    X
# 16  per 100 square km of land area    2.0    X
# 17  per 100 square km of land area    1.8    X
# 18  per 100 square km of land area    1.8    X
#
#                            Flag Description  Note
# 11  Figure from international organizations   NaN
# 12  Figure from international organizations   NaN
# 13  Figure from international organizations   NaN
# 14  Figure from international organizations   NaN
# 15  Figure from international organizations   NaN
# 16  Figure from international organizations   NaN
# 17  Figure from international organizations   NaN
# 18  Figure from international organizations   NaN

# %%
#colombia.set_index('Year', inplace=True)
#ecuador.set_index('Year Code', inplace=True)
georgia.set_index('Year Code', inplace=True)
#peru.set_index('Year Code', inplace=True)
vietnam.set_index('Year Code', inplace=True)
#colombia = colombia.tail(9)
#ecuador = ecuador.tail(10)
georgia = georgia.tail(8)
#peru = peru.tail(10)
vietnam = vietnam.tail(8)

# %%
dfSummary=pd.DataFrame({"Country":['Georgia','Vietnam']})
dfList=[georgia,vietnam ]

min,max,mean,std = [],[],[],[]
for df in dfList:
    min.append("%.2f" % df['Value'].min())
    max.append("%.2f" % df['Value'].max())
    mean.append("%.2f" % df['Value'].mean())
    std.append("%.2f" % df['Value'].std())

dfSummary['Mean']=mean
dfSummary['S.D.']=std
dfSummary['Min.']=min
dfSummary['Max.']=max

# %%
dfSummary.loc[2]=['Colombia',None,None,None,None]
dfSummary.loc[3]=['Ecuador',None,None,None,None]
dfSummary.loc[4]=['Peru',None,None,None,None]

# %%
dfSummary
# Out:
#     Country  Mean  S.D.  Min.  Max.
# 0   Georgia  2.00  0.19  1.80  2.30
# 1   Vietnam  0.79  0.14  0.70  1.00
# 2  Colombia  None  None  None  None
# 3   Ecuador  None  None  None  None
# 4      Peru  None  None  None  None

# %%
df = dfSummary
# Initialise the Word document
doc = docx.Document()
# Initialise the table
t = doc.add_table(rows=1, cols=df.shape[1])
# Add borders
t.style = 'TableGrid'
# Add the column headings
for j in range(df.shape[1]):
    t.cell(0, j).text = df.columns[j]
# Add the body of the data frame
for i in range(df.shape[0]):
    row = t.add_row()
    for j in range(df.shape[1]):
        cell = df.iat[i, j]
        row.cells[j].text = str(cell)
# Save the Word doc
doc.save('Rail lines density.csv.docx')
# Out:
# /home/dila-isi/.conda/envs/homealarms/lib/python3.10/site-packages/docx/styles/styles.py:139: UserWarning: style lookup by style_id is deprecated. Use style name as key instead.
#   return self._get_style_id_from_style(self[style_name], style_type)

# %%
plt.subplots(figsize=(8, 5))
#plt.plot(0, label='Colombia', color='green', marker='o')
#plt.plot(ecuador['Value'], label='Ecuador', color='steelblue', marker='o')
plt.plot(georgia['Value'], label='Georgia', color='purple', marker='o')
#plt.plot(peru['Value'], label='Peru', color='black', marker='o')
plt.plot(vietnam['Value'], label='Vietnam', color='red', marker='o')
plt.title('Rail lines density (total route in km per 100 square km of land area)', fontsize=12)
plt.legend(title='Country')
plt.ylim(0.60,2.50)
plt.ylabel('route in km per 100 square km of land area', fontsize=14)
#plt.figure(figsize=(15,100))


#plt.plot(range(10), linestyle='--', marker='o', color='b', label='line with marker')
plt.legend()
